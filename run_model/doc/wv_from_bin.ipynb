# %%
from gensim.models import KeyedVectors

a = 'Good muffins cost $3.88\nin New York.  Please buy me\ntwo of them.\nThanks, e.g. the tokenizer sed script written by    Robert  McIntyre.'
all_vec_path = '/home/qcdong/models/embedding/wikipedia-pubmed-and-PMC-w2v.bin'
wv_from_bin = KeyedVectors.load_word2vec_format(all_vec_path, binary=True)
print(type(wv_from_bin))
# Out:
# <class 'gensim.models.keyedvectors.KeyedVectors'>

# %%
print(wv_from_bin.__dict__.keys())
key_index_dict = wv_from_bin.__dict__['key_to_index']
print(type(key_index_dict))
v = wv_from_bin['disease']
print(v)
# Out:
# dict_keys(['vector_size', 'index_to_key', 'next_index', 'key_to_index', 'vectors', 'norms', 'expandos', 'mapfile_path', 'lifecycle_events'])
# <class 'dict'>
# [ 8.68635066e-03 -1.45051911e-01  2.75097340e-01  5.54031096e-02
#  -1.92709565e-02 -7.51560600e-03  2.35239808e-02  2.05535173e-01
#   1.69549379e-02  2.07311794e-01 -1.39732853e-01 -1.93052337e-01
#  -2.19461638e-02 -4.03515756e-01 -3.24841231e-01 -1.99908048e-01
#  -1.37098972e-02 -7.57707749e-03  3.72244418e-01 -7.73806646e-02
#  -2.21138168e-02  3.49388778e-01 -4.64541703e-01 -8.22397992e-02
#   9.18237343e-02  1.37090251e-01 -9.75289941e-02 -4.86036092e-02
#  -5.58811985e-02  1.91142529e-01 -8.51811320e-02  6.73139915e-02
#  -8.37773159e-02 -2.47956678e-01  9.95221063e-02  2.28288919e-01
#  -7.51699647e-03 -7.59914964e-02 -2.65753895e-01  2.52853066e-01
#  -8.94636512e-02  4.63039503e-02  1.76776752e-01 -3.54781270e-01
#   4.59315240e-01 -3.35390233e-02  1.52774826e-01  9.73990858e-02
# ...
